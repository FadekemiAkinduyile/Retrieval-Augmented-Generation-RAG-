# %%
# !pip install langchain langchain-community sentence_transformers faiss-cpu ctransformers

# %%
# ! pip install pypdf
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 5.4 MB/s eta 0:00:00
# ...

# %%
from langchain_community.document_loaders import DirectoryLoader, TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.llms import CTransformers
from langchain import PromptTemplate
from langchain.chains import RetrievalQA
from huggingface_hub import hf_hub_download
from IPython.display import display, HTML
import json
import time
import pathlib
from langchain_community.document_loaders import PyPDFLoader, OnlinePDFLoader

# %% [markdown]
# ### Document processing

# %%
# define what documents to load
loader = PyPDFLoader("Llama 2 - arxiv.pdf")
#loader = PyPDFDirectoryLoader("pdfs")
documents = loader.load()

# %%
# interpret information in the documents
documents = loader.load()
splitter = RecursiveCharacterTextSplitter(chunk_size=500,
                                          chunk_overlap=10)
texts = splitter.split_documents(documents)
print(len(texts))
# Out:
# 586

# %%
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2",
    model_kwargs={'device': 'cpu'})

# create the local database
db = FAISS.from_documents(texts, embeddings)
#db.save_local("faiss")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# ...

# %%
#test
query = "what is the education history?"
answer = db.similarity_search(query)
#answer = db.similarity_search(query, k=2)

# %% [markdown]
# ### Prepare a LLM2 - 13B

# %%
# prepare the template we will use when prompting the AI
template = """Use the following pieces of information to answer the user's question.
If you don't know the answer, just say that you don't know, don't try to make up an answer.
Context: {context}
Question: {question}
Only return the helpful answer below and nothing else.
Helpful answer:
"""

# load the language model
config = {'max_new_tokens': 100, 'temperature': 0.4}

model_name_or_path = "TheBloke/Llama-2-13B-chat-GGML"
model_basename = "llama-2-13b-chat.ggmlv3.q5_1.bin" # the model is in bin format
model_path = hf_hub_download(repo_id=model_name_or_path, filename=model_basename)



llm = CTransformers(model=model_path,
                    model_type='llama',
                    config={'max_new_tokens': 100, 'temperature': 0.4})

# Load the embeddings model
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2",
    model_kwargs={'device': 'cuda'})

# Specify the path to the directory containing the "index.faiss" file
#index_directory = "/projects/llama/faiss/"

# Load the local database
# db = FAISS.load_local(index_directory, embeddings)


# prepare a version of the llm pre-loaded with the local content
retriever = db.as_retriever(search_kwargs={'k': 2})
prompt = PromptTemplate(
    template=template,
    input_variables=['context', 'question'])

QA_LLM = RetrievalQA.from_chain_type(llm=llm,
                                     chain_type='stuff',
                                     retriever=retriever,
                                     return_source_documents=True,
                                     chain_type_kwargs={'prompt': prompt})
# Out:
# llama-2-13b-chat.ggmlv3.q5_1.bin:   0%|          | 0.00/9.76G [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %% [markdown]
# ## Ask Questions about the document

# %%
def query(model, question):
    model_path = model.combine_documents_chain.llm_chain.llm.model
    model_name = pathlib.Path(model_path).name
    time_start = time.time()
    output = model({'query': question})
    response = output["result"]
    time_elapsed = time.time() - time_start
    display(HTML(f'<code>{model_name} response time: {time_elapsed:.02f} sec</code>'))
    display(HTML(f'<strong>Question:</strong> {question}'))
    display(HTML(f'<strong>Answer:</strong> {response}'))

# %%
query(QA_LLM, "What are fine-tuning requirements for llama 2?")
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain 0.1.0 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# <code>llama-2-13b-chat.ggmlv3.q5_1.bin response time: 626.66 sec</code>
# <strong>Question:</strong> What are fine-tuning requirements for llama 2?
# <strong>Answer:</strong> To ensure safe deployment of Llama 2, developers should perform safety testing and tuning tailored to their specific architecture. This includes using supervised fine-tuning (SFT) and reinforcement learning with human feedback (RLHF) to align the model's outputs to human preferences for helpfulness and safety.

# %%
query(QA_LLM, "What was llama 2 evaluation result ?")
# Out:
# <code>llama-2-13b-chat.ggmlv3.q5_1.bin response time: 406.09 sec</code>
# <strong>Question:</strong> What was llama 2 evaluation result ?
# <strong>Answer:</strong> Llama 2 models outperformed Llama 1 models, with the 70B model improving results on MMLU and BBH by approximately 5 and 8 points, respectively, compared to Llama 1 65B.
